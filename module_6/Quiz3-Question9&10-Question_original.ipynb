# %% [markdown]
# ## Heart Disease Prediction— Multiclass Classification

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from sklearn.metrics import classification_report, accuracy_score

# %%
# import the heart disease dataset
dataset = "http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data"

column_names =  ['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal','class']

# read the csv
dataset = pd.read_csv(dataset, names=column_names)

# remove missing data with "?"
df = dataset[~dataset.isin(['?'])]

#drop rows with NaN values from DataFrame
df = df.dropna(axis=0)

# checking data type of the dataframe
print (df.dtypes)
# Out:
# age         float64
# sex         float64
# cp          float64
# trestbps    float64
# chol        float64
# fbs         float64
# restecg     float64
# thalach     float64
# exang       float64
# oldpeak     float64
# slope       float64
# ca           object
# thal         object
# class         int64
# dtype: object

# %%
# transform data to numeric because ca and thal are object datatypes
data = df.apply(pd.to_numeric)
print(data.dtypes)
# Out:
# age         float64
# sex         float64
# cp          float64
# trestbps    float64
# chol        float64
# fbs         float64
# restecg     float64
# thalach     float64
# exang       float64
# oldpeak     float64
# slope       float64
# ca          float64
# thal        float64
# class         int64
# dtype: object

# %%
# plot histograms for each variable
data.hist(figsize = (15, 15))
plt.show()

# %%
# create X and Y datasets for training
X = data.iloc[:,0:13]
y = data.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2,shuffle = False, random_state=90)

# There are 4 classes so we need to one-hot encode them
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
# create model
model = Sequential()
model.add(Dense(10, input_dim=13, kernel_initializer='normal', activation='relu'))
model.add(Dense(8, kernel_initializer='normal', activation='relu'))
model.add(Dense(4, kernel_initializer='normal', activation='relu'))
model.add(Dense(5, activation='softmax'))

filepath="CNN_Model-{epoch:02d}-{val_accuracy:.2f}.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
# compile model
model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.

# %%
train_model = model.fit(X_train, y_train, epochs=60, batch_size=8, verbose = 1, validation_data=(X_test,y_test),callbacks=[callbacks_list])
# Out:
# Epoch 1/60
# 2024-10-03 21:55:18.203865: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
#  1/30 [>.............................] - ETA: 4s - loss: 1.6065 - accuracy: 0.0000e+00
# Epoch 1: val_accuracy improved from -inf to 0.48333, saving model to CNN_Model-01-0.48.h5
# 30/30 [==============================] - 0s 3ms/step - loss: 1.5406 - accuracy: 0.5359 - val_loss: 1.4904 - val_accuracy: 0.4833
# Epoch 2/60
#  1/30 [>.............................] - ETA: 0s - loss: 1.3758 - accuracy: 0.5000
# Epoch 2: val_accuracy did not improve from 0.48333
# 30/30 [==============================] - 0s 694us/step - loss: 1.3454 - accuracy: 0.5527 - val_loss: 1.4422 - val_accuracy: 0.4833
# Epoch 3/60
#  1/30 [>.............................] - ETA: 0s - loss: 0.6545 - accuracy: 1.0000
# Epoch 3: val_accuracy did not improve from 0.48333
# 30/30 [==============================] - 0s 677us/step - loss: 1.2897 - accuracy: 0.5527 - val_loss: 1.4091 - val_accuracy: 0.4833
# Epoch 4/60
#  1/30 [>.............................] - ETA: 0s - loss: 1.4736 - accuracy: 0.3750
# Epoch 4: val_accuracy did not improve from 0.48333
# 30/30 [==============================] - 0s 641us/step - loss: 1.2857 - accuracy: 0.5527 - val_loss: 1.4244 - val_accuracy: 0.4833
# Epoch 5/60
#  1/30 [>.............................] - ETA: 0s - loss: 1.3515 - accuracy: 0.6250
# Epoch 5: val_accuracy did not improve from 0.48333
# 30/30 [==============================] - 0s 683us/step - loss: 1.2732 - accuracy: 0.5527 - val_loss: 1.3863 - val_accuracy: 0.4833
# Epoch 6/60
#  1/30 [>.............................] - ETA: 0s - loss: 1.4876 - accuracy: 0.3750
# Epoch 6: val_accuracy did not improve from 0.48333
# 30/30 [==============================] - 0s 658us/step - loss: 1.2678 - accuracy: 0.5527 - val_loss: 1.3839 - val_accuracy: 0.4833
# Epoch 7/60
#  1/30 [>.............................] - ETA: 0s - loss: 1.5511 - accuracy: 0.3750
# Epoch 7: val_accuracy did not improve from 0.48333
# 30/30 [==============================] - 0s 646us/step - loss: 1.2462 - accuracy: 0.5527 - val_loss: 1.3761 - val_accuracy: 0.4833
# Epoch 8/60
#  1/30 [>.............................] - ETA: 0s - loss: 1
60
#  1/30 [>.............................] - ETA: 0s - loss: 0.4006 - accuracy: 0.8750
# Epoch 25: val_accuracy did not improve from 0.48333
# 30/30 [==============================] - 0s 657us/step - loss: 1.0205 - accuracy: 0.5527 - val_loss: 1.1835 - val_accuracy: 0.4833
# Epoch 26/60
#  1/30 [>.............................] - ETA: 0s - loss: 0.8634 - accuracy: 0.7500
# Epoch 26: val_accuracy improved from 0.48333 to 0.50000, saving model to CNN_Model-26-0.50.h5
# 30/30 [==============================] - 0s 916us/step - loss: 1.0133 - accuracy: 0.5527 - val_loss: 1.1864 - val_accuracy: 0.5000
# Epoch 27/60
#  1/30 [>.............................] - ETA: 0s - loss: 0.8130 - accuracy: 0.6250
# Epoch 27: val_accuracy did not improve from 0.50000
# 30/30 [==============================] - 0s 626us/step - loss: 0.9989 - accuracy: 0.5865 - val_loss: 1.1842 - val_accuracy: 0.4833
# Epoch 28/60
#  1/30 [>.............................] - ETA: 0s - loss: 1.3751 - accuracy: 0.7500
# Epoch 28: val_accuracy did not improve from 0.50000
# 30/30 [==============================] - 0s 641us/step - loss: 1.0070 - accuracy: 0.6076 - val_loss: 1.1729 - val_accuracy: 0.4500
# Epoch 29/60
#  1/30 [>.............................] - ETA: 0s - loss: 1.1999 - accuracy: 0.5000
# Epoch 29: val_accuracy did not improve from 0.50000
# 30/30 [==============================] - 0s 678us/step - loss: 0.9914 - accuracy: 0.6118 - val_loss: 1.1753 - val_accuracy: 0.5000
# Epoch 30/60
#  1/30 [>.............................] - ETA: 0s - loss: 0.9791 - accuracy: 0.7500
# Epoch 30: val_accuracy did not improve from 0.50000
# 30/30 [==============================] - 0s 1ms/step - loss: 0.9873 - accuracy: 0.6203 - val_loss: 1.1613 - val_accuracy: 0.4667
# Epoch 31/60
#  1/30 [>.............................] - ETA: 0s - loss: 0.8356 - accuracy: 0.8750
# Epoch 31: val_accuracy improved from 0.50000 to 0.51667, saving model to CNN_Model-31-0.52.h5
# 30/30 [==============================] - 0s 1ms/step - loss: 0.9964 - accuracy: 0.6034 - val_loss: 1.1791 - val_accuracy: 0.5167
# Epoch 32/60
#  1/30 [>.............................] - ETA: 0s - loss: 0.8974 - accuracy: 0.6250
# Epoch 32: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 868us/step - loss: 0.9794 - accuracy: 0.6287 - val_loss: 1.1518 - val_accuracy: 0.4833
# Epoch 33/60
#  1/30 [>.............................] - ETA: 0s - loss: 0.7380 - accuracy: 0.7500
# Epoch 33: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 2ms/step - loss: 0.9789 - accuracy: 0.6203 - val_loss: 1.1788 - val_accuracy: 0.5167
# Epoch 34/60
#  1/30 [>.............................] - ETA: 0s - loss: 0.2671 - accuracy: 1.0000
# Epoch 34: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 2ms/step - loss: 0.9796 - accuracy: 0.6160 - val_loss: 1.1459 - val_accuracy: 0.4667
# Epoch 35/60
#  1/30 [>.............................] - ETA: 0s - loss: 0.7164 - accuracy: 0.7500
# Epoch 35: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 785us/step - loss: 1.0181 - accuracy: 0.6160 - val_loss: 1.1444 - val_accuracy: 0.5000
# Epoch 36/60
#  1/30 [>.............................] - ETA: 0s - loss: 1.1856 - accuracy: 0.3750
# Epoch 36: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 759us/step - loss: 0.9666 - accuracy: 0.6287 - val_loss: 1.1715 - val_accuracy: 0.5167
# Epoch 37/60
#  1/30 [>.............................] - ETA: 0s - loss: 0.7744 - accuracy: 0.8750
# Epoch 37: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 700us/step - loss: 0.9547 - accuracy: 0.6371 - val_loss: 1.1361 - val_accuracy: 0.4833
# Epoch 38/60
#  1/30 [>.............................] - ETA: 0s - loss: 0.8075 - accuracy: 0.7500
# Epoch 38: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 709us/step - loss: 0.9637 - accuracy: 0.6203 - val_loss: 1.1606 - val_accuracy: 0.5167
# Epoch 39/60
#  1/30 [>.............................] - ETA: 0s - loss: 0.8046 - accuracy: 0.7500
# Epoch 39: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 678us/step - loss: 0.9618 - accuracy: 0.6329 - val_loss: 1.1369 - val_accuracy: 0.5000
# Epoch 40/60
#  1/30 [>.............................] - ETA: 0s - loss: 0.7076 - accuracy: 0.7500
# Epoch 40: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 695us/step - loss: 0.9488 - accuracy: 0.6245 - val_loss: 1.1327 - val_accuracy: 0.4833
# Epoch 41/60
#  1/30 [>.............................] - ETA: 0s - loss: 0.7992 - accuracy: 0.6250
# Epoch 41: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s
val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 813us/step - loss: 0.9115 - accuracy: 0.6371 - val_loss: 1.1534 - val_accuracy: 0.5167
# Epoch 59/60
#  1/30 [>.............................] - ETA: 0s - loss: 1.3929 - accuracy: 0.3750
# Epoch 59: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 695us/step - loss: 0.9316 - accuracy: 0.6414 - val_loss: 1.0743 - val_accuracy: 0.4833
# Epoch 60/60
#  1/30 [>.............................] - ETA: 0s - loss: 0.9967 - accuracy: 0.5000
# Epoch 60: val_accuracy did not improve from 0.51667
# 30/30 [==============================] - 0s 680us/step - loss: 0.9166 - accuracy: 0.6498 - val_loss: 1.0796 - val_accuracy: 0.4833

# %%
# Plotting the model
plt.plot(train_model.history['accuracy'], marker='.')
plt.plot(train_model.history['val_accuracy'], marker='.')
plt.title('model accuracy')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.grid()
plt.legend(['accuracy', 'val_accuracy'], loc='lower right')
plt.savefig('model_accuracy.png')
plt.close()

plt.plot(train_model.history['loss'], marker='.')
plt.plot(train_model.history['val_loss'], marker='.')
plt.title('model loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.grid()
plt.legend(['loss', 'val_loss'], loc='upper right')
plt.savefig('model_loss.png')
plt.close()

# %%
pred = model.predict(X_test)

print('Maximum Probabilities of Test Dataset: ',np.max(pred, axis=-1))
# Out:
# 2/2 [==============================] - 0s 988us/step
# Maximum Probabilities of Test Dataset:  [0.8876235  0.92554766 0.89733225 0.4573581  0.5466266  0.2686137
#  0.48079085 0.2692306  0.3114654  0.7922693  0.2703592  0.2686137
#  0.2686137  0.84637636 0.884481   0.9303524  0.6100206  0.51691985
#  0.7850969  0.5655869  0.7924551  0.71961653 0.93451256 0.9109161
#  0.2686137  0.2686137  0.27199116 0.79640496 0.8557858  0.2686137
#  0.2711808  0.2686137  0.58671045 0.79296553 0.569377   0.7425416
#  0.8761739  0.8210915  0.7097529  0.2686137  0.92867345 0.2686137
#  0.9349582  0.4982772  0.2686137  0.2686137  0.6994476  0.908059
#  0.35380986 0.90421265 0.2711844  0.2686137  0.69668627 0.94794637
#  0.2686137  0.27097645 0.42645678 0.2686137  0.2686137  0.884057  ]

# %%
for i in pred:
    if(np.max(i) > 0.8):
        print("Critical")
    elif(np.max(i) > 0.5):
        print("moderate or severe")
    elif(np.max(i) > 0.3):
        print("mild or moderate")
    else:
        print("None")
# Out:
# Critical
# Critical
# Critical
# mild or moderate
# moderate or severe
# None
# mild or moderate
# None
# mild or moderate
# moderate or severe
# None
# None
# None
# Critical
# Critical
# Critical
# moderate or severe
# moderate or severe
# moderate or severe
# moderate or severe
# moderate or severe
# moderate or severe
# Critical
# Critical
# None
# None
# None
# moderate or severe
# Critical
# None
# None
# None
# moderate or severe
# moderate or severe
# moderate or severe
# moderate or severe
# Critical
# Critical
# moderate or severe
# None
# Critical
# None
# Critical
# mild or moderate
# None
# None
# moderate or severe
# Critical
# mild or moderate
# Critical
# None
# None
# moderate or severe
# Critical
# None
# None
# mild or moderate
# None
# None
# Critical

# %%
# need to take argmax if it is a multiclass problem
y_pred = np.argmax(pred, axis=1)
y_test = np.argmax(y_test, axis=1)


print('Classification Accuracy: '+str(accuracy_score(y_test, y_pred) * 100)+' %')
# Out:
# Classification Accuracy: 48.333333333333336 %
